# %%
import numpy as np
import json
import matplotlib.pyplot as plt
import os

# %%
out_dir = "models/20_units/reward5/True_True_25_True_500_False_IAP500/DistQ/DistQ_softmax_5_0.1_0.99_0.0001_0_q_init:0_1/run0"

# %%
path = os.path.join(out_dir, "reward_for_plot_training.json")

# %%
a = json.load(open(path))

# %%
durations = []
for perf_dict in a.values():
    durations.append(perf_dict["episode_duration"])

durations
# Out:
# [968, 1368, 1523, 658, 1468]
